# %%
import cv2
import re
import json
import pytesseract
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('comp01.jpeg') # Carrega a imagem
plt.imshow(img) # Exibe a imagem

# %%
config = r'--tessdata-dir tessdata'
texto = pytesseract.image_to_string(img, lang='por', config=config)
print(texto)
# Out:
# SUPER SEU SUPERMERCADO
# CHPJ: 04,955.138/0001-03 TE: 431165174003]
# AV 15 NOVENBRO, 325, nfru aogªu;%rn. HONTE CARHELO, H6
# Fone: (34) 3842-2341
#
# CODIGO DESCRICAO ==
# 794900 700282 REFRI 3ÍONL LATA CO
# TESGOOZS0418Á PRO PULLHAN BÚRGER 6
# 898958658588 TENPERO POLETTO DRY
# 76981 18070601 PINENTA REINO SAROM
# 7891143001206 QUETJO POLENG 1486 C
# 2024918007423 NUSSAÁRELA POP FAT KG
# 7043982009362 CARNE HAHBUR KIJOIA
# 7043962008242 CARNE HAMBUR KIJOIA
# QUANTIDADE TOTAL DE ITENS o
#
# VALOR TOTAL R$
# FORMA DE PAGAMENTO VALOR PÃGO R$
# CREDITO 107,62
#
# “Consulte pela Chave de Acesso en
# https://portalsped,fazenda.ng.uov.br/portalnfce
# 3176 0204 9551 3800 0103 6500 5000 3053 8017 6710 9960
#
# Nunero: 305380
#
# Serie: 5
#
# Enissao: 03/02/2026 18:54:07
#
# Protocolo de autorizaçao: 131269187989300
#
# 03/02/2026 18:54:]
# CONSUMIDOR NÃO IDZNTIFICADO
#
# 14,82: Estad, 19,78
#
# REDE
# CoNMPR: 34699033 3 D tOTda
# ÉS?ÉR SEU SUPERMERCADO  03.02.26-18:53
# S e CNPJ/CPF:04.955, 198/0001-03
# ENDERÉCO;AV 15 UÉ»IIUUHHRKI.MS
#
# E -UF;MONTE CARNELO-NG
# '%w%u ANAAAAKKANKA! 862
# “ RUTORIZAÇÃO: 137019 ,
# SALDO DISP, . e craneeo
# MU[:%MLJIÚILLB 560
# TRAGCÃA ºlÍBÍ fron Flf.?fv SEA
# TEA Enp.: 001 Poy. >-
# A Versão; 2”120?5
#
# []i:er.;-idur: .Oí;l ÉRHIUR CRIST
